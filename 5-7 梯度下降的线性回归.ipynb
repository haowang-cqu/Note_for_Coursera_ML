# %%
import numpy as np
import matplotlib.pyplot as plt

# 载入数据集
data_set = np.loadtxt('./data1.csv', dtype=np.double, delimiter=',')
print(data_set.shape)

# 观察数据集
plt.scatter(data_set[:, 0], data_set[:, 1], marker='x')
plt.show()
# Out:
# (97, 2)
